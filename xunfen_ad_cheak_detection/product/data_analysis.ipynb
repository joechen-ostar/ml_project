# %%
import pandas as pd

# %%
outline_path = "../data/round1_iflyad_anticheat_traindata.txt"
online_path = "../data/round1_iflyad_anticheat_testdata_feature.txt"

# %%
#显示所有列
pd.set_option('display.max_columns', None)

#显示所有行
pd.set_option('display.max_rows', None)

#设置value的显示长度为100，默认为50
pd.set_option('max_colwidth',100)

# %%
df1 = pd.read_csv(outline_path, sep = "\t")

# %%
df1.head()
# Out:
#                                                   sid  label  \
# 0  d7460126-e071-4979-9ee8-42f72777a28a-1560090701088      1
# 1  b660d559-db97-4b5f-9bd2-2450cb89ce77-1560050740125      1
# 2  f49a740e-66c3-4605-9b67-4d3079fe69cb-1560089145219      0
# 3  fd60d096-f168-4540-b782-729d64d0fcc6-1560062539740      0
# 4  a037b032-a5c7-40ea-9161-26b118b12406-1560079380269      1
#
#                             pkgname              ver  \
# 0  2d2664e827bcbb8b07100c7fbe072e9b          11.11.0
# 1                             empty              NaN
# 2  16b81f93f4b1a35cebbf15f07683f171  3.2.1.0524.1958
# 3                             empty            4.7.5
# 4  cf4821986014a7fef9d7b7ad8de655e4              228
#
#                        adunitshowid                       mediashowid  \
# 0  907d0f8c29663840491577a21c7b612a  ca64a500000d84c8fcb8a0587d0e1e0c
# 1  10199dc8fea2e173525bc3151bd84312  3f2fc57a6e1f9c6fa4464c25cc1e88a3
# ...
